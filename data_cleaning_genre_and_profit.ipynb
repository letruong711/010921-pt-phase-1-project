# %%
import pandas as pd
import numpy as np

# %%
movie_gross = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz')

imdb_names = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
imdb_titles = pd.read_csv('data/zippedData/imdb.title.akas.csv.gz')
imdb_titles_basics = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
imdb_crew = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
imdb_prinipals = pd.read_csv('data/zippedData/imdb.title.principals.csv.gz')
imdb_ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')

rt_reviews = pd.read_csv('data/zippedData/rotten_tomatoes_critic_reviews.csv.gz')
rt_moves = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')

tmdb_movies = pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
tn_movie_budgets = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz')

# %%
tn_movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
tn_movie_profit = tn_movie_budgets.copy(deep='True')
tn_movie_profit = tn_movie_profit.rename(columns={'movie':'primary_title'})
tn_movie_profit.drop(['release_date','id'], axis=1, inplace=True)
tn_movie_profit.to_csv('data/movie_profit.csv', index=False)

# %%
imdb_titles_basics = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
imdb_titles_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-197307f0cc06> in <module>
# ----> 1 tn_movie_profit.to_numeric('worldwide_gross')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_numeric'

# %%
imdb_titles_basics.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
imdb_titles_basics.dropna(subset=['original_title','runtime_minutes'], inplace=True)

# %%
imdb_titles_basics.isna().sum()
# Out:
# tconst                0
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes       0
# genres             2169
# dtype: int64

# %%
imdb_genres = imdb_titles_basics.copy(deep='True')
imdb_genres.drop(['tconst', 'original_title', 'start_year'], axis=1, inplace=True)
imdb_genres.to_csv('data/imdb_genres.csv', index=False)
imdb_genres
# Out:
#                                             primary_title  runtime_minutes  \
# 0                                               Sunghursh            175.0
# 1                         One Day Before the Rainy Season            114.0
# 2                              The Other Side of the Wind            122.0
# 4                                The Wandering Soap Opera             80.0
# 5                                             A Thin Life             75.0
# ...                                                   ...              ...
# 146135                                      The Rehearsal             51.0
# 146136  Illenau - die Geschichte einer ehemaligen Heil...             84.0
# 146137                                          Safeguard             90.0
# 146139                                Kuambil Lagi Hatiku            123.0
# 146142                                             6 Gunn            116.0
#
#                       genres
# 0         Action,Crime,Drama
# ...

# %%
#try and get profit somehow. Cannot convert object into int to do math. 
profit_and_genre = pd.merge(tn_movie_profit, imdb_genres, on='primary_title')
profit_and_genre["worldwide_gross"] = profit_and_genre["worldwide_gross"].astype(str).astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-44aadd3ffaa7> in <module>
#       1 profit_and_genre = pd.merge(tn_movie_profit, imdb_genres, on='primary_title')
# ----> 2 profit_and_genre["worldwide_gross"] = profit_and_genre["worldwide_gross"].astype(str).astype('int64')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-2e56f18e33c8> in <module>
# ----> 1 profit_and_genre.replace['Avatar']['runtime_miutes' == 180.0]
#
# TypeError: 'method' object is not subscriptable

# %%
imdb_titles_basics[imdb_titles_basics['primary_title']=='Avatar']
# Out:
#           tconst primary_title original_title  start_year  runtime_minutes  \
# 17060  tt1775309        Avatar          Abatâ        2011             93.0
#
#        genres
# 17060  Horror

# %%
imdb_genres[imdb_genres['primary_title']=='Avatar']
# Out:
#       primary_title  runtime_minutes  genres
# 17060        Avatar             93.0  Horror

# %%
rt_moves = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')
rt_movie_info = rt_moves.copy(deep='True')
rt_movie_info.drop(['rotten_tomatoes_link', 'movie_info', 'critics_consensus', 'content_rating',
                   'authors', 'original_release_date', 'production_company'])
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# ...

# %%
# Out:
#            nconst              primary_name  birth_year  death_year  \
# 32      nm0071116         Valérie Benguigui      1961.0      2013.0
# 38      nm0073426           Laxmikant Berde      1954.0      2004.0
# 62      nm0083767            Fernando Birri      1925.0      2017.0
# 64      nm0085193                Bill Black      1926.0      1965.0
# 71      nm0087190          Maurice Blanchot      1907.0      2003.0
# ...           ...                       ...         ...         ...
# 599067  nm9425078                  Lil Peep      1996.0      2017.0
# 600210  nm9211845            Jan C. Gabriel      1940.0      2010.0
# 602878  nm7455311  Joost van der Westhuizen      1971.0      2017.0
# 603895  nm8201131  Lewis Lucky Carrillo III      1968.0      2017.0
# 604364  nm8659676            Zygmunt Bauman      1925.0      2017.0
#
#             primary_profession                         known_for_titles
# 32          actress,soundtrack  tt0119344,tt2179121,tt2150708,tt1068646
# ...
