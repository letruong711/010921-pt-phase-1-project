# %%
import pandas as pd

# %%
imdb_crew = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
imdb_crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
imdb_crew.directors = imdb_crew.directors.str.split(',')
imdb_crew.dropna(subset=['directors'], inplace=True)
imdb_direct=imdb_crew.explode('directors')

# %%
imdb_direct
# Out:
#            tconst   directors              writers
# 0       tt0285252   nm0899854            nm0899854
# 2       tt0462036   nm1940585            nm1940585
# 3       tt0835418   nm0151540  nm0310087,nm0841532
# 4       tt0878654   nm0089502            nm0284943
# 4       tt0878654   nm2291498            nm0284943
# ...           ...         ...                  ...
# 146139  tt8999974  nm10122357           nm10122357
# 146140  tt9001390   nm6711477            nm6711477
# 146141  tt9001494  nm10123242                  NaN
# 146141  tt9001494  nm10123248                  NaN
# 146142  tt9004986   nm4993825            nm4993825
#
# [163535 rows x 3 columns]

# %%
imdb_direct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163535 entries, 0 to 146142
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     163535 non-null  object
#  1   directors  163535 non-null  object
#  2   writers    126518 non-null  object
# dtypes: object(3)
# memory usage: 5.0+ MB

# %%
imdb_direct.to_csv('data/direct_rating.csv', index=False)

# %%
imdb_direct.duplicated().sum()
# Out:
# 0

# %%
imdb_ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')
imdb_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
imdb_ratings.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
imdb_ratings.duplicated().sum()
# Out:
# 0

# %%
imdb_movie_ratings = imdb_ratings.copy(deep=True)
imdb_movie_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
imdb_director_ratings = pd.merge(imdb_direct, imdb_movie_ratings, on='tconst' )
# imdb_direct_ratings.drop(['tconst', 'writers_x', 'writers_y', 'numvotes', 'tconst', 'writers',
#                          'directors_x', 'directors_y'], axis=1, inplace=True)

# %%
imdb_director_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86031 entries, 0 to 86030
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         86031 non-null  object
#  1   directors      86031 non-null  object
#  2   writers        73650 non-null  object
#  3   averagerating  86031 non-null  float64
#  4   numvotes       86031 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.9+ MB

# %%
imdb_director_ratings = imdb_director_ratings.rename(columns={'directors':'nconst'})

# %%
imdb_director_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86031 entries, 0 to 86030
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         86031 non-null  object
#  1   nconst         86031 non-null  object
#  2   writers        73650 non-null  object
#  3   averagerating  86031 non-null  float64
#  4   numvotes       86031 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.9+ MB

# %%
imdb_director_ratings.isna().sum()
# Out:
# tconst               0
# directors            0
# writers          12381
# averagerating        0
# numvotes             0
# dtype: int64

# %%
imdb_director_ratings.dropna()
# Out:
#           tconst   directors               writers  averagerating  numvotes
# 0      tt0285252   nm0899854             nm0899854            3.9       219
# 1      tt0462036   nm1940585             nm1940585            5.5        18
# 2      tt0835418   nm0151540   nm0310087,nm0841532            5.0      8147
# 3      tt0878654   nm0089502             nm0284943            5.8       875
# 4      tt0878654   nm2291498             nm0284943            5.8       875
# ...          ...         ...                   ...            ...       ...
# 86024  tt8931532   nm0855646  nm0855646,nm10106977            6.9        14
# 86025  tt8947660  nm10097606            nm10097614            8.1        21
# 86028  tt8954732   nm0737517   nm0076820,nm2997602            6.0     13993
# 86029  tt8991416   nm7731173             nm7731173            6.7        13
# 86030  tt9004986   nm4993825             nm4993825            8.4         7
#
# [73650 rows x 5 columns]

# %%
imdb_director_ratings['directors'].astype(str)
# Out:
# 0        nm0899854
# 1        nm1940585
# 2        nm0151540
# 3        nm0089502
# 4        nm2291498
#            ...
# 86026    nm0827830
# 86027    nm0839064
# 86028    nm0737517
# 86029    nm7731173
# 86030    nm4993825
# Name: directors, Length: 86031, dtype: object

# %%
imdb_names = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
imdb_director_names = imdb_names.copy(deep=True)

# %%
imdb_director_names
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
imdb_director_names.isna().sum()
# Out:
# nconst                     0
# primary_name               0
# birth_year            523912
# death_year            599865
# primary_profession     51340
# known_for_titles       30204
# dtype: int64

# %%
imdb_director_names.dropna()
# Out:
#            nconst              primary_name  birth_year  death_year  \
# 32      nm0071116         Valérie Benguigui      1961.0      2013.0
# 38      nm0073426           Laxmikant Berde      1954.0      2004.0
# 62      nm0083767            Fernando Birri      1925.0      2017.0
# 64      nm0085193                Bill Black      1926.0      1965.0
# 71      nm0087190          Maurice Blanchot      1907.0      2003.0
# ...           ...                       ...         ...         ...
# 599067  nm9425078                  Lil Peep      1996.0      2017.0
# 600210  nm9211845            Jan C. Gabriel      1940.0      2010.0
# 602878  nm7455311  Joost van der Westhuizen      1971.0      2017.0
# 603895  nm8201131  Lewis Lucky Carrillo III      1968.0      2017.0
# 604364  nm8659676            Zygmunt Bauman      1925.0      2017.0
#
#             primary_profession                         known_for_titles
# 32          actress,soundtrack  tt0119344,tt2179121,tt2150708,tt1068646
# ...

# %%
imdb_director_names.astype(str)['nconst'].map(lambda x: type(x))
# Out:
# 0         <class 'str'>
# 1         <class 'str'>
# 2         <class 'str'>
# 3         <class 'str'>
# 4         <class 'str'>
#               ...
# 606643    <class 'str'>
# 606644    <class 'str'>
# 606645    <class 'str'>
# 606646    <class 'str'>
# 606647    <class 'str'>
# Name: nconst, Length: 606648, dtype: object

# %%
# imdb_directors = pd.merge(imdb_director_names, imdb_director_ratings, on)
imdb_directors = pd.merge(imdb_director_names, imdb_director_ratings, 
                          left_on = 'directors', right_on = 'nconst')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-9d41557014bf> in <module>
#       1 # imdb_directors = pd.merge(imdb_director_names, imdb_director_ratings, on)
# ----> 2 imdb_directors = pd.merge(imdb_director_names, imdb_director_ratings,
#       3                           left_on = 'directors', right_on = 'nconst')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
