# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Helping Microsoft take over the film industry.
#
# **Authors:** Le Truong
# ***

# %% [markdown]
# ## Overview

# %% [markdown]
# Microsoft is one of the world's longstanding leaders in technology. Aside from corporate sponsorships and Windows Media Player, they have remained silent and distant from the film industry. **This is all about to change!** Microsoft has recently teamed up with Flatiron School to help them identify what variable they need to focus on to produce a successful movie. There are many factors that determine a film's successes. In this presentation, I will focus on three variables that correlate with ratings to help point Microsoft in the right direction.

# %% [markdown]
# ## Data Understanding
#
# - This data used for this presented was provided by Flatiron and contains IMDB ratings, genres, production budgets, and runtimes.

# %% [markdown]
# # Questions to be Answered
# ### Overarching Question: What information can we provide to Microsoft that will be usefull when creating a successful film?
# - Does a movie's runtime impact it's ratings?
# - Are there specific genres?
# - Is there a correlation between a large production budget and higher ratings?

# %% [markdown]
# ## Base codes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## **First Question**: Do longer movies(<=300 minutes) have lower ratings than shorter movies?

# %%
imdb_ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')
imdb_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
imdb_titles_basics = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
imdb_titles_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
imdb_time_rating = pd.merge(imdb_titles_basics, imdb_ratings, on='tconst')
imdb_time_rating.drop(['tconst'], axis=1, inplace=True)
imdb_time_rating
# Out:
#                          primary_title              original_title  \
# 0                            Sunghursh                   Sunghursh
# 1      One Day Before the Rainy Season             Ashad Ka Ek Din
# 2           The Other Side of the Wind  The Other Side of the Wind
# 3                      Sabse Bada Sukh             Sabse Bada Sukh
# 4             The Wandering Soap Opera       La Telenovela Errante
# ...                                ...                         ...
# 73851                 Diabolik sono io            Diabolik sono io
# 73852                Sokagin Çocuklari           Sokagin Çocuklari
# 73853                        Albatross                   Albatross
# 73854       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73851        2019             75.0           Documentary            6.2
# 73852        2019             98.0          Drama,Family            8.7
# 73853        2017              NaN           Documentary            8.5
# 73854        2019              NaN                   NaN            6.6
# 73855        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73851         6
# 73852       136
# 73853         8
# 73854         5
# 73855        11
#
# [73856 rows x 7 columns]

# %%
imdb_time_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   primary_title    73856 non-null  object
#  1   original_title   73856 non-null  object
#  2   start_year       73856 non-null  int64
#  3   runtime_minutes  66236 non-null  float64
#  4   genres           73052 non-null  object
#  5   averagerating    73856 non-null  float64
#  6   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
imdb_time_rating.duplicated().sum()
# Out:
# 0

# %%
imdb_time_rating.isna().sum()
# Out:
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes    7620
# genres              804
# averagerating         0
# numvotes              0
# dtype: int64

# %%
imdb_time_rating.dropna(subset=['runtime_minutes', 'genres'], inplace=True)
imdb_time_rating
# Out:
#                          primary_title              original_title  \
# 0                            Sunghursh                   Sunghursh
# 1      One Day Before the Rainy Season             Ashad Ka Ek Din
# 2           The Other Side of the Wind  The Other Side of the Wind
# 4             The Wandering Soap Opera       La Telenovela Errante
# 6                      Joe Finds Grace             Joe Finds Grace
# ...                                ...                         ...
# 73849        Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 73850                     Swarm Season                Swarm Season
# 73851                 Diabolik sono io            Diabolik sono io
# 73852                Sokagin Çocuklari           Sokagin Çocuklari
# 73855                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                      genres  averagerating  \
# 0            2013            175.0          Action,Crime,Drama            7.0
# 1            2019            114.0             Biography,Drama            7.2
# 2            2018            122.0                       Drama            6.9
# 4            2017             80.0        Comedy,Drama,Fantasy            6.5
# 6            2017             83.0  Adventure,Animation,Comedy            8.1
# ...           ...              ...                         ...            ...
# 73849        2019            130.0                       Drama            8.4
# 73850        2019             86.0                 Documentary            6.2
# 73851        2019             75.0                 Documentary            6.2
# 73852        2019             98.0                Drama,Family            8.7
# 73855        2019             72.0                 Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 4           119
# 6           263
# ...         ...
# 73849       365
# 73850         5
# 73851         6
# 73852       136
# 73855        11
#
# [65720 rows x 7 columns]

# %%
imdb_time_rating['averagerating'].astype('int64')
# Out:
# 0        7
# 1        7
# 2        6
# 4        6
# 6        8
#         ..
# 73849    8
# 73850    6
# 73851    6
# 73852    8
# 73855    6
# Name: averagerating, Length: 65720, dtype: int64

# %%
imdb_time_rating['runtime_minutes'].astype('int64')
# Out:
# 0        175
# 1        114
# 2        122
# 4         80
# 6         83
#         ...
# 73849    130
# 73850     86
# 73851     75
# 73852     98
# 73855     72
# Name: runtime_minutes, Length: 65720, dtype: int64

# %%
imdb_time_rating = imdb_time_rating[imdb_time_rating['runtime_minutes'] < 300]

# %%
fig, ax = plt.subplots(figsize = (20,20))
copy = imdb_time_rating.copy()
copy = copy[copy.runtime_minutes < 300]
sns.regplot(copy['runtime_minutes'],copy['averagerating'], ax=ax)
ax.set_title('Runtimes vs Average Ratings')
ax.set_xlabel('Runtime')
ax.set_ylabel('Average Rating')
ax.set(ylim=(0, 10))
ax.set(xlim=(0,300));
# Out:
# C:\Users\letru\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_run = copy['runtime_minutes']
y_rating = copy['averagerating']
coef = np.corrcoef(x_run, y_rating)
print(coef)
# Out:
# [[ 1.         -0.04418462]
#  [-0.04418462  1.        ]]

# %% [markdown]
# - Based on the visualization, we were able to see a slight negative correlation. Upon calculating the Pearson Correlation Coefficent, we were able to show there was no significant correlation between longer movies and lower ratings.

# %% [markdown]
# ## **Second Question**: Are there specific genres that get higher ratings(>=6.0)?

# %%
df = pd.read_csv('data/time_rating.csv')
df.head()
# Out:
#                      primary_title  start_year  runtime_minutes  \
# 0                        Sunghursh        2013            175.0
# 1  One Day Before the Rainy Season        2019            114.0
# 2       The Other Side of the Wind        2018            122.0
# 3         The Wandering Soap Opera        2017             80.0
# 4                  Joe Finds Grace        2017             83.0
#
#                        genres  averagerating  numvotes
# 0          Action,Crime,Drama            7.0        77
# 1             Biography,Drama            7.2        43
# 2                       Drama            6.9      4517
# 3        Comedy,Drama,Fantasy            6.5       119
# 4  Adventure,Animation,Comedy            8.1       263

# %%
df.genres = df.genres.str.split(',')
df=df.explode('genres')
df
# Out:
#                          primary_title  start_year  runtime_minutes  \
# 0                            Sunghursh        2013            175.0
# 0                            Sunghursh        2013            175.0
# 0                            Sunghursh        2013            175.0
# 1      One Day Before the Rainy Season        2019            114.0
# 1      One Day Before the Rainy Season        2019            114.0
# ...                                ...         ...              ...
# 65716                     Swarm Season        2019             86.0
# 65717                 Diabolik sono io        2019             75.0
# 65718                Sokagin Çocuklari        2019             98.0
# 65718                Sokagin Çocuklari        2019             98.0
# 65719                       Drømmeland        2019             72.0
#
#             genres  averagerating  numvotes
# 0           Action            7.0        77
# 0            Crime            7.0        77
# 0            Drama            7.0        77
# 1        Biography            7.2        43
# 1            Drama            7.2        43
# ...            ...            ...       ...
# 65716  Documentary            6.2         5
# 65717  Documentary            6.2         6
# 65718        Drama            8.7       136
# 65718       Family            8.7       136
# 65719  Documentary            6.5        11
#
# [118437 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize = (20,15))
sns.histplot(data=df, x="averagerating", hue="genres", multiple="stack")
ax.set_title('Colors of the Genre')
ax.set_xlabel('Average Rating')
ax.set_ylabel('Number of Movies with X Genre(s)')
plt.xlim(6,10)
fig.savefig('images/Genre.png');

# %%
fig, ax = plt.subplots(figsize = (20,15))
sns.histplot(data=df, x="averagerating", hue="genres", multiple="stack")
ax.set_title('Colors of the Genre')
ax.set_xlabel('Average Rating')
ax.set_ylabel('Number of Movies with X Genre(s)')
plt.xlim(6,10)
plt.ylim(0,200);

# %% [markdown]
# - We are determinging a successful movie as anything greater than 6.0. Based on visualizations above, we can see there are specific genres that do often score higher than others.
#     - Action, drama, documentaries, adventure, mystery, and SciFi films usually score higher than others.

# %% [markdown]
# ## Third Question: How will product budgets impact ratings?

# %%
budget = pd.read_csv('data/movie_profit.csv')
productbudget = budget.copy(deep=True)
productbudget
# Out:
#                                     primary_title production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross
# 0      $760,507,625  $2,776,345,279
# 1      $241,063,875  $1,045,663,875
# 2       $42,762,350    $149,762,350
# 3      $459,005,868  $1,403,013,963
# 4      $620,181,382  $1,316,721,747
# ...             ...             ...
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041
#
# [5782 rows x 4 columns]

# %%
imdb_title_basics = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
MG = imdb_title_basics.copy(deep=True)
MG.drop(['original_title', 'start_year', 'runtime_minutes'], axis=1, inplace=True)
MG
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                       genres
# 0         Action,Crime,Drama
# 1            Biography,Drama
# 2                      Drama
# 3               Comedy,Drama
# 4       Comedy,Drama,Fantasy
# ...                      ...
# 146139                 Drama
# 146140           Documentary
# 146141                Comedy
# 146142                   NaN
# 146143           Documentary
#
# [146144 rows x 3 columns]

# %%
MGB = pd.merge(MG, productbudget, on='primary_title')
MGB
# Out:
#          tconst  primary_title                    genres production_budget  \
# 0     tt0249516     Foodfight!   Action,Animation,Comedy       $45,000,000
# 1     tt0293429  Mortal Kombat  Action,Adventure,Fantasy       $20,000,000
# 2     tt0326592  The Overnight                       NaN          $200,000
# 3     tt3844362  The Overnight            Comedy,Mystery          $200,000
# 4     tt0337692    On the Road   Adventure,Drama,Romance       $25,000,000
# ...         ...            ...                       ...               ...
# 3810  tt9678962           Fuel         Documentary,Sport        $2,500,000
# 3811  tt9729206          Diner                     Crime        $5,000,000
# 3812  tt9805168        Traitor      Action,Drama,Romance       $22,000,000
# 3813  tt9844102            Ray                     Crime       $40,000,000
# 3814  tt9893078        Sublime               Documentary        $1,800,000
#
#      domestic_gross worldwide_gross
# 0                $0         $73,706
# 1       $70,433,227    $122,133,227
# 2        $1,109,808      $1,165,996
# 3        $1,109,808      $1,165,996
# 4          $720,828      $9,313,302
# ...             ...             ...
# 3810       $174,255        $174,255
# 3811    $12,592,907     $12,592,907
# 3812    $23,530,831     $27,882,226
# 3813    $75,305,995    $124,823,094
# 3814             $0              $0
#
# [3815 rows x 6 columns]

# %%
imdb_ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')
MR = imdb_ratings.copy(deep=True)
MR.drop(['numvotes'], axis=1, inplace=True)
MR
# Out:
#            tconst  averagerating
# 0      tt10356526            8.3
# 1      tt10384606            8.9
# 2       tt1042974            6.4
# 3       tt1043726            4.2
# 4       tt1060240            6.5
# ...           ...            ...
# 73851   tt9805820            8.1
# 73852   tt9844256            7.5
# 73853   tt9851050            4.7
# 73854   tt9886934            7.0
# 73855   tt9894098            6.3
#
# [73856 rows x 2 columns]

# %%
PR = pd.merge(MR, MGB, on='tconst')
PR.drop(['tconst', 'domestic_gross', 'worldwide_gross'], axis=1, inplace=True)
PR = PR.sort_values(by=['production_budget'], ascending=False)
PR
# Out:
#       averagerating                primary_title                      genres  \
# 208             7.6                   Robin Hood                         NaN
# 2569            6.6                   Robin Hood      Action,Adventure,Drama
# 2055            5.3                   Robin Hood   Action,Adventure,Thriller
# 1293            6.3                   Robin Hood                Action,Drama
# 1397            7.1            The Peanuts Movie  Adventure,Animation,Comedy
# ...             ...                          ...                         ...
# 1635            2.2  Snow White: A Deadly Summer                      Horror
# 2126            7.0                         1982                       Drama
# 2372            6.7               The Invitation        Drama,Horror,Mystery
# 43              6.2      The Sisterhood of Night      Drama,Mystery,Thriller
# 1135            6.2                         Slam        Comedy,Drama,Romance
#
#      production_budget
# 208        $99,000,000
# 2569       $99,000,000
# 2055       $99,000,000
# 1293       $99,000,000
# 1397       $99,000,000
# ...                ...
# 1635        $1,000,000
# 2126        $1,000,000
# 2372        $1,000,000
# 43          $1,000,000
# 1135        $1,000,000
#
# [2875 rows x 4 columns]

# %%
PR.dropna()
# Out:
#       averagerating                primary_title                      genres  \
# 2569            6.6                   Robin Hood      Action,Adventure,Drama
# 2055            5.3                   Robin Hood   Action,Adventure,Thriller
# 1293            6.3                   Robin Hood                Action,Drama
# 1397            7.1            The Peanuts Movie  Adventure,Animation,Comedy
# 1921            6.4              Alien: Covenant      Horror,Sci-Fi,Thriller
# ...             ...                          ...                         ...
# 1635            2.2  Snow White: A Deadly Summer                      Horror
# 2126            7.0                         1982                       Drama
# 2372            6.7               The Invitation        Drama,Horror,Mystery
# 43              6.2      The Sisterhood of Night      Drama,Mystery,Thriller
# 1135            6.2                         Slam        Comedy,Drama,Romance
#
#      production_budget
# 2569       $99,000,000
# 2055       $99,000,000
# 1293       $99,000,000
# 1397       $99,000,000
# 1921       $97,000,000
# ...                ...
# 1635        $1,000,000
# 2126        $1,000,000
# 2372        $1,000,000
# 43          $1,000,000
# 1135        $1,000,000
#
# [2867 rows x 4 columns]

# %%
PR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2875 entries, 208 to 1135
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   averagerating      2875 non-null   float64
#  1   primary_title      2875 non-null   object
#  2   genres             2867 non-null   object
#  3   production_budget  2875 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 112.3+ KB

# %%
PR['production_budget'] = PR['production_budget'].astype(str)

# %%
PR['production_budget'] = PR.production_budget.replace(',','', regex=True)
PR['genres'] = PR['genres'].dropna()
PR = PR.sort_values(by=['production_budget'], ascending=False)
PR = PR.drop_duplicates()
PR
# Out:
#       averagerating      primary_title                      genres  \
# 208             7.6         Robin Hood                         NaN
# 1397            7.1  The Peanuts Movie  Adventure,Animation,Comedy
# 2569            6.6         Robin Hood      Action,Adventure,Drama
# 2055            5.3         Robin Hood   Action,Adventure,Thriller
# 1293            6.3         Robin Hood                Action,Drama
# ...             ...                ...                         ...
# 1951            6.4            Closure                       Drama
# 2751            6.7      Cheap Thrills          Comedy,Crime,Drama
# 2655            6.5        Open Secret                 Documentary
# 2251            7.9            Closure        Comedy,Drama,Romance
# 70              4.9               Cure                       Drama
#
#      production_budget
# 208          $99000000
# 1397         $99000000
# 2569         $99000000
# 2055         $99000000
# 1293         $99000000
# ...                ...
# 1951           $100000
# 2751           $100000
# 2655           $100000
# 2251           $100000
# 70              $10000
#
# [2871 rows x 4 columns]

# %%
PR.info
# Out:
# <bound method DataFrame.info of       averagerating                primary_title                      genres  \
# 208             7.6                   Robin Hood                         NaN
# 2569            6.6                   Robin Hood      Action,Adventure,Drama
# 2055            5.3                   Robin Hood   Action,Adventure,Thriller
# 1293            6.3                   Robin Hood                Action,Drama
# 1397            7.1            The Peanuts Movie  Adventure,Animation,Comedy
# ...             ...                          ...                         ...
# 1635            2.2  Snow White: A Deadly Summer                      Horror
# 2126            7.0                         1982                       Drama
# 2372            6.7               The Invitation        Drama,Horror,Mystery
# 43              6.2      The Sisterhood of Night      Drama,Mystery,Thriller
# 1135            6.2                         Slam        Comedy,Drama,Romance
#
#      production_budget
# 208        $99,000,000
# 2569       $99,000,000
# 2055       $99,000,000
# 1293       $99,000,000
# 1397       $99,000,000
# ...                ...
# 1635        $1,000,000
# 2126        $1,000,000
# 2372        $1,000,000
# 43          $1,000,000
# 1135        $1,000,000
#
# [2875 rows x 4 columns]>

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(15, 50))
sns.set_theme(style="white")
sns.barplot(x="averagerating", y="production_budget", data=PR)
ax.set_title('Production Budget and Ratings')
ax.set_xlabel('Rating')
ax.set_ylabel('Production Budget');

# %% [markdown]
# - ~2,900 values compared. We see a slight correlation between higher production value and higher movie ratings.
#     - There was a film that had a 1,400 dollar production budget and almost got a six rating compared to a film with a 1.03 million dollar budget with a rating of just over 4.

# %%
x_run = copy['averagerating']
y_rating = copy['production_budget']
coef = np.corrcoef(x_run, y_rating)
print(coef)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'production_budget'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-0923743f215e> in <module>
#       1 x_run = copy['averagerating']
# ----> 2 y_rating = copy['production_budget']
#       3 coef = np.corrcoef(x_run, y_rating)
#       4 print(coef)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'production_budget'

# %% [markdown]
# ## Conclusions
# Our job was to identify factors we believed will help Micosoft produce a successful film. The factor I looked into was rating and compared it with movie runtimes, genres, and production budgets. Our findings were as follows:
#
# - There are no correlation between movie's runtime and its ratings.
# - There are specific genre's commonly rated higher than others.
# - There might be a slight correlation between a movie's production budget and its ratings.
#
# Well, what can Microsoft do with this data?
#
# We were able to show that runtime and production budget doesn't matter towards ratings so it can focus on other important factors such as genre. If Microsoft can focus and produce a film that is a mixture of action, drama, adventure, and SciFi genres with a decent runtime and a great script, it will produce a film that will get great ratings and hopefully make profit.

# %% [markdown]
# ## What's next? How can we use this data in the future?
#
# Questions to consider:
#
# * Is there too much data?
#     - Clean up the data more and look at less information.
# * Is the analysis not deep enough?
#     - Look at other variables such as ratings and total profit, independent production versus big production, and cast.
#     - Look at using information from Rottentomatoes
